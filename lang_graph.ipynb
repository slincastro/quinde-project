# %%
# !pip install langchain
# !pip install langchain-openai
# !pip install langgraph
# !pip install grandalf
# Out:
# Requirement already satisfied: langchain in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (0.3.21)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.45 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langchain) (0.3.46)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.7 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langchain) (0.3.7)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langchain) (0.3.18)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langchain) (2.10.6)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langchain) (2.0.39)
# Requirement already satisfied: requests<3,>=2 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.45->langchain) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.45->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.45->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.45->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2025.1.31)
# Requirement already satisfied: anyio in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.45->langchain) (3.0.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: langchain-openai in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (0.3.9)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.45 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langchain-openai) (0.3.46)
# Requirement already satisfied: openai<2.0.0,>=1.66.3 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langchain-openai) (1.66.3)
# Requirement already satisfied: tiktoken<1,>=0.7 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langchain-openai) (0.9.0)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.45->langchain-openai) (0.3.18)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.45->langchain-openai) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.45->langchain-openai) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.45->langchain-openai) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.45->langchain-openai) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.45->langchain-openai) (4.12.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.45->langchain-openai) (2.10.6)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from openai<2.0.0,>=1.66.3->langchain-openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from openai<2.0.0,>=1.66.3->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from openai<2.0.0,>=1.66.3->langchain-openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from openai<2.0.0,>=1.66.3->langchain-openai) (0.9.0)
# Requirement already satisfied: sniffio in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from openai<2.0.0,>=1.66.3->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from openai<2.0.0,>=1.66.3->langchain-openai) (4.67.1)
# Requirement already satisfied: regex>=2022.1.18 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2.32.3)
# Requirement already satisfied: idna>=2.8 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.66.3->langchain-openai) (3.10)
# Requirement already satisfied: certifi in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.66.3->langchain-openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.66.3->langchain-openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.66.3->langchain-openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.45->langchain-openai) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.45->langchain-openai) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.45->langchain-openai) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.45->langchain-openai) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<1.0.0,>=0.3.45->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<1.0.0,>=0.3.45->langchain-openai) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (2.3.0)
# Requirement already satisfied: langgraph in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (0.3.18)
# Requirement already satisfied: langchain-core<0.4,>=0.1 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langgraph) (0.3.46)
# Requirement already satisfied: langgraph-checkpoint<3.0.0,>=2.0.10 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langgraph) (2.0.21)
# Requirement already satisfied: langgraph-prebuilt<0.2,>=0.1.1 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langgraph) (0.1.3)
# Requirement already satisfied: langgraph-sdk<0.2.0,>=0.1.42 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langgraph) (0.1.58)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langchain-core<0.4,>=0.1->langgraph) (0.3.18)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langchain-core<0.4,>=0.1->langgraph) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langchain-core<0.4,>=0.1->langgraph) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langchain-core<0.4,>=0.1->langgraph) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langchain-core<0.4,>=0.1->langgraph) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langchain-core<0.4,>=0.1->langgraph) (4.12.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langchain-core<0.4,>=0.1->langgraph) (2.10.6)
# Requirement already satisfied: msgpack<2.0.0,>=1.1.0 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langgraph-checkpoint<3.0.0,>=2.0.10->langgraph) (1.1.0)
# Requirement already satisfied: httpx>=0.25.2 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langgraph-sdk<0.2.0,>=0.1.42->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langgraph-sdk<0.2.0,>=0.1.42->langgraph) (3.10.15)
# Requirement already satisfied: anyio in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (4.9.0)
# Requirement already satisfied: certifi in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (1.0.7)
# Requirement already satisfied: idna in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.1->langgraph) (3.0.0)
# Requirement already satisfied: requests<3,>=2 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.1->langgraph) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.1->langgraph) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.1->langgraph) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4,>=0.1->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4,>=0.1->langgraph) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.1->langgraph) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.1->langgraph) (2.3.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (1.3.1)
# Collecting grandalf
#   Downloading grandalf-0.8-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: pyparsing in /Users/slincastro/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from grandalf) (3.2.1)
# Downloading grandalf-0.8-py3-none-any.whl (41 kB)
# Installing collected packages: grandalf
# Successfully installed grandalf-0.8

# %%
import json

api_key = None
with open('config.json') as f:
    data = json.load(f)
    api_key = data['openai']['api_key']

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_openai import ChatOpenAI

reflection_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are a viral twitter influencer grading a tweet. Generate critique and recommendations for the user's tweet."
            "Always provide detailed recommendations, including requests for length, virality, style, etc.",
        ),
        MessagesPlaceholder(variable_name="messages"),
    ]
)

generation_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are a twitter techie influencer assistant tasked with writing excellent twitter posts."
            " Generate the best twitter post possible for the user's request."
            " If the user provides critique, respond with a revised version of your previous attempts.",
        ),
        MessagesPlaceholder(variable_name="messages"),
    ]
)


#llm = ChatOpenAI()
llm = ChatOpenAI(api_key=api_key)
generate_chain = generation_prompt | llm
reflect_chain = reflection_prompt | llm

# %%
from typing import List, Sequence

from dotenv import load_dotenv
load_dotenv()

from langchain_core.messages import BaseMessage, HumanMessage
from langgraph.graph import END, MessageGraph

REFLECT = "reflect"
GENERATE = "generate"


def generation_node(state: Sequence[BaseMessage]):
    return generate_chain.invoke({"messages": state})


def reflection_node(messages: Sequence[BaseMessage]) -> List[BaseMessage]:
    res = reflect_chain.invoke({"messages": messages})
    return [HumanMessage(content=res.content)]


builder = MessageGraph()
builder.add_node(GENERATE, generation_node)
builder.add_node(REFLECT, reflection_node)
builder.set_entry_point(GENERATE)


def should_continue(state: List[BaseMessage]):
    if len(state) > 6:
        return END
    return REFLECT


builder.add_conditional_edges(GENERATE, should_continue)
builder.add_edge(REFLECT, GENERATE)

graph = builder.compile()
print(graph.get_graph().draw_mermaid())
graph.get_graph().print_ascii()

if __name__ == "__main__":
    print("Hello LangGraph")
    inputs = HumanMessage(content="""Make this tweet better:"
                                    @LangChainAI
            — newly Tool Calling feature is seriously underrated.

            After a long wait, it's  here- making the implementation of agents across different models with function calling - super easy.

            Made a video covering their newest blog post

                                  """)
    
    
    response = graph.invoke(inputs)

    print(response)
# Out:
# %%{init: {'flowchart': {'curve': 'linear'}}}%%
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	generate(generate)
# 	reflect(reflect)
# 	__end__([<p>__end__</p>]):::last
# 	__start__ --> generate;
# 	reflect --> generate;
# 	generate -.-> reflect;
# 	generate -.-> __end__;
# 	classDef default fill:#f2f0ff,line-height:1.2
# 	classDef first fill-opacity:0
# 	classDef last fill:#bfb6fc
#
#           +-----------+
#           | __start__ |
#           +-----------+
#                 *
#                 *
#                 *
#           +----------+
#           | generate |
#           +----------+
#           ***        ...
#          *              .
#        **                ..
# +---------+           +---------+
# | reflect |           | __end__ |
# +---------+           +---------+
# Hello LangGraph
# [HumanMessage(content='Make this tweet better:"\n                                    @LangChainAI\n            — newly Tool Calling feature is seriously underrated.\n\n            After a long wait, it\'s  here- making the implementation of agents across different models with function calling - super easy.\n\n            Made a video covering their newest blog post\n\n                                  ', additional_kwargs={}, response_metadata={}, id='528ce6ae-1877-4d53-8fb2-4ebee6a1745e'), AIMessage(content='"@LangChainAI\'s new Tool Calling feature is a game-changer! 🚀 Finally, seamless agent implementation across various models is a breeze. Check out my latest video where I dive deep into their latest blog post. #AI #Tech"', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 51, 'prompt_tokens': 113, 'total_tokens': 164, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-BD2h5BLp3YtSdEWfAQtI7tkBcL9ev', 'finish_reason': 'stop', 'logprobs': None}, id='run-b2bbb43d-3293-490e-8cc7-09c5ffdfbeb4-0', usage_metadata={'input_tokens': 113, 'output_tokens': 51, 'total_tokens': 164, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content="The revised tweet is more engaging and compelling, with added emojis and hashtags to attract more attention and showcase enthusiasm. Consider adding more specific details about your video to give followers a preview or reason to click on the link. Overall, the tweet is concise and impactful, but try to maintain a fine balance between being succinct and providing enough information to generate interest. Consider the tweet's length for optimal engagement and ensure it's no longer than 280 characters.", additional_kwargs={}, response_metadata={}, id='96719114-b98e-41cf-aeaf-96d5fc0ae251'), AIMessage(content='"@LangChainAI\'s new Tool Calling feature is revolutionary! 🌟 Seamlessly integrate agents across models with ease. Watch my latest video breakdown of their blog post for an inside look. Don\'t miss out! #AI #Tech #Innovation"', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 52, 'prompt_tokens': 260, 'total_tokens': 312, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-BD2h7wd2IV5VzolXZ5mzVdo5KP1X8', 'finish_reason': 'stop', 'logprobs': None}, id='run-343afa67-b324-46bb-9927-7ba8b363d178-0', usage_metadata={'input_tokens': 260, 'output_tokens': 52, 'total_tokens': 312, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='This revised tweet is concise, engaging, and to the point, with the added emojis and hashtags making it more captivating. I would suggest making it even more interactive and engaging by adding a call to action at the end, such as "Watch now" or "Learn more." Additionally, consider incorporating specific highlights from the blog post or video to create intrigue and entice followers to click on the link. Striking a balance between brevity and providing enough context is crucial for effective communication on Twitter. Keep the tweet length within the 280-character limit for optimal engagement.', additional_kwargs={}, response_metadata={}, id='cc13e2a9-89c5-4e13-b03f-01cd10d543de'), AIMessage(content='"Exciting news! 🚀 @LangChainAI\'s new Tool Calling feature streamlines agent integration across models effortlessly. I\'ve broken down their latest blog post in my video. Curious to learn mo ...

# %%
# Function to convert the conversation to Markdown format
def convert_to_markdown(conversation):
    md_output = "# **Tweet Improvement Discussion**\n\n"
    
    for i, msg in enumerate(conversation):
        role = "**Human:**" if isinstance(msg, HumanMessage) else "**AI:**"
        step_number = f"## **{i + 1}️⃣ {'Human' if isinstance(msg, HumanMessage) else 'AI'} Message**\n"
        formatted_msg = f"```md\n{msg.content}\n```\n"

        md_output += f"{step_number}{role}\n{formatted_msg}\n"
    
    return md_output

# Convert conversation to Markdown
markdown_text = convert_to_markdown(response)  # Ensure `response` is a list of HumanMessage/AIMessage objects

# Save to a Markdown file
with open("conversation.md", "w", encoding="utf-8") as f:
    f.write(markdown_text)

print("✅ Markdown file 'conversation.md' has been generated!")
# Out:
# ✅ Markdown file 'conversation.md' has been generated!
